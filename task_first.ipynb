# %% [markdown]
# <a href="https://colab.research.google.com/github/mitra13126/CS-SBU-MachineLearning-BSc-2022/blob/97222004/task_first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-aa9bf1f3-ac41-44e8-afbb-047680e66cc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa9bf1f3-ac41-44e8-afbb-047680e66cc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"mitagh","key":"1dc0739c8742e61e9dece3121f043b1e"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls
# Out:
# kaggle.json  sample_data

# %%
# !kaggle datasets download -d iabhishekofficial/mobile-price-classification
# Out:
# ...
#   0% 0.00/70.6k [00:00<?, ?B/s]
# 100% 70.6k/70.6k [00:00<00:00, 48.1MB/s]

# %%
# !ls
# Out:
# kaggle.json  mobile-price-classification.zip  sample_data

# %%
import zipfile
zip_ref = zipfile.ZipFile('mobile-price-classification.zip', 'r')
zip_ref.extractall('files')
zip_ref.close()
# !ls
# Out:
# files  kaggle.json  mobile-price-classification.zip  sample_data

# %%
import pandas as pd
mobile_df=pd.read_csv('/content/files/train.csv')
mobile_test_df=pd.read_csv('/content/files/test.csv')
pd.set_option("display.max_columns", None)

# %%
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
mobile_df[mobile_df['price_range']==3]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 6              1821     0          1.7         0   4       1          10
# 10              769     1          2.9         1   0       0           9
# 11             1520     1          2.2         0   5       1          33
# 16              838     0          0.5         0   1       1          13
# 17              595     0          0.9         1   7       1          23
# ...             ...   ...          ...       ...  ..     ...         ...
# 1991           1882     0          2.0         0  11       1          44
# 1993           1467     1          0.5         0   0       0          18
# 1994            858     0          2.2         0   1       0          50
# 1997           1911     0          0.9         1   1       1          36
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
mobile_df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10,6)

# %%
plt.hist(mobile_df.battery_power, bins=20, rwidth=0.8)
plt.xlabel('battery_power')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.clock_speed, bins=20, rwidth=0.8)
plt.xlabel('battery_pclock_speedower')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.fc, bins=20, rwidth=0.8)
plt.xlabel('fc')
plt.ylabel('count')
plt.show()

# %%
upper_fc = mobile_df.fc.mean() + 3*mobile_df.fc.std()
lower_fc = mobile_df.fc.mean() - 3*mobile_df.fc.std()
mobile_df[(mobile_df['fc'] > upper_fc) | (mobile_df['fc'] < lower_fc)]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 95             1137     1          1.0         0  18       0           7
# 226            1708     1          2.4         1  18       1          49
# 305            1348     0          2.0         0  18       0          52
# 1387           1533     1          1.1         1  18       1          17
# 1406           1731     1          2.3         1  18       0          60
# 1416           1448     0          0.5         1  18       0           2
# 1554           1957     0          1.2         1  18       1          36
# 1693            695     0          0.5         0  18       1          12
# 1705           1290     1          1.4         1  19       1          35
# 1880           1720     0          1.6         0  18       1           2
# 1882            591     0          2.1         1  18       1          16
# 1888           1544     0          2.4         0  18       1          12
#
# ...

# %%
plt.hist(mobile_df.int_memory, bins=20, rwidth=0.8)
plt.xlabel('int_memory')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.mobile_wt, bins=20, rwidth=0.8)
plt.xlabel('mobile_wt')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.n_cores, bins=20, rwidth=0.8)
plt.xlabel('n_cores')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.pc, bins=20, rwidth=0.8)
plt.xlabel('pc')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.px_height, bins=20, rwidth=0.8)
plt.xlabel('px_height')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.px_width, bins=20, rwidth=0.8)
plt.xlabel('px_width')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.ram, bins=20, rwidth=0.8)
plt.xlabel('ram')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.sc_h, bins=20, rwidth=0.8)
plt.xlabel('sc_h')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.sc_w, bins=20, rwidth=0.8)
plt.xlabel('sc_w')
plt.ylabel('count')
plt.show()

# %%
plt.hist(mobile_df.sc_w, bins=20, rwidth=0.8)
plt.xlabel('sc_w')
plt.ylabel('count')
plt.show()

# %%
mobile_df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %%
mobile_test_df.describe()
# Out:
#                 id  battery_power         blue  clock_speed     dual_sim  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    1248.510000     0.516000     1.540900     0.517000
# std     288.819436     432.458227     0.499994     0.829268     0.499961
# min       1.000000     500.000000     0.000000     0.500000     0.000000
# 25%     250.750000     895.000000     0.000000     0.700000     0.000000
# 50%     500.500000    1246.500000     1.000000     1.500000     1.000000
# 75%     750.250000    1629.250000     1.000000     2.300000     1.000000
# max    1000.000000    1999.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep   mobile_wt  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean      4.593000     0.487000    33.652000     0.517500   139.51100
# std       4.463325     0.500081    18.128694     0.280861    34.85155
# ...
